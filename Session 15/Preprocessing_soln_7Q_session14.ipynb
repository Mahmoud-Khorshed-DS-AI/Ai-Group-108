# %% [markdown]
# # Task
#
# 1- Read data
#
# 2- print details about data
#
# 3-check Duplicate for every column
#
# 4- print number of unique for  every column
#
# 5- check any data quantity issues
#
# 6- solve all 7 problems with writing comments ✔️
#
# ![DataQuality.png](attachment:DataQuality.png)

# %% [markdown]
# # 1- import and read data

# %%
import pandas as pd 

path='D:\Work\Cources\American\G4\Session 15\DataQuality.csv'
df=pd.read_csv(path.replace("\\", "/"))
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      A          1         23      Germany
# 5   6     555   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          5  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6   Italy
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %% [markdown]
# # 2 print details about data

# %%
df.shape
# Out:
# (10, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          10 non-null     int64
#  1   Id         10 non-null     int64
#  2   Name       10 non-null     object
#  3   Birthday   10 non-null     object
#  4   Gender     10 non-null     object
#  5   IsTeacher  10 non-null     int64
#  6   #StudentS  10 non-null     int64
#  7   Country    10 non-null     object
#  8   City       9 non-null      object
# dtypes: int64(4), object(5)
# memory usage: 852.0+ bytes

# %%
df[df.duplicated(subset='Id',keep=False)]
# Out:
#    #   Id   Name    Birthday Gender  IsTeacher  #StudentS  Country    City
# 4  5  555   Alex  15/03/2000      A          1         23  Germany  Berlin
# 5  6  555  Peter  1983-12-01      M          1         10    Italy    Rome

# %%
df.sample(5)
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
# 8   9     999    Anne    5/9/1992      F          0          5  Switzerland
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
#
#      City
# 6   Italy
# 9    Rome
# 8  Geneva
# 0  Dublin
# 7  Lisbon

# %%
df[df.duplicated(subset='Id',keep=False)].to_csv('Duplicate_id.csv')

# %%
for col in df.columns:
    print(col)
    print(df[df.duplicated(subset=col,keep=False)])
    print('------------------------')
# Out:
# #
# Empty DataFrame
# Columns: [#, Id, Name, Birthday, Gender, IsTeacher, #StudentS, Country, City]
# Index: []
# ------------------------
# Id
#    #   Id   Name    Birthday Gender  IsTeacher  #StudentS  Country    City
# 4  5  555   Alex  15/03/2000      A          1         23  Germany  Berlin
# 5  6  555  Peter  1983-12-01      M          1         10    Italy    Rome
# ------------------------
# Name
# Empty DataFrame
# Columns: [#, Id, Name, Birthday, Gender, IsTeacher, #StudentS, Country, City]
# Index: []
# ------------------------
# Birthday
# Empty DataFrame
# Columns: [#, Id, Name, Birthday, Gender, IsTeacher, #StudentS, Country, City]
# Index: []
# ------------------------
# Gender
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# ...

# %%
df.sample()
# Out:
#    #   Id    Name  Birthday Gender  IsTeacher  #StudentS Country   City
# 6  7  777  Calvin  5/5/1995      M          0          0   Italy  Italy

# %%
df.nunique()
# Out:
# #            10
# Id            9
# Name         10
# Birthday     10
# Gender        3
# IsTeacher     2
# #StudentS     6
# Country       9
# City          8
# dtype: int64

# %%
df.corr()
# Out:
#                   #        Id  IsTeacher  #StudentS
# #          1.000000  0.529777   0.071067   0.272438
# Id         0.529777  1.000000   0.406227   0.624571
# IsTeacher  0.071067  0.406227   1.000000   0.897034
# #StudentS  0.272438  0.624571   0.897034   1.000000

# %%
df.columns
# Out:
# Index(['#', 'Id', 'Name', 'Birthday', 'Gender', 'IsTeacher', '#StudentS',
#        'Country', 'City'],
#       dtype='object')

# %%
df['Name'].value_counts()
# Out:
# Name
# John      1
# Mery      1
# Alice     1
# Mark      1
# Alex      1
# Peter     1
# Calvin    1
# Roxane    1
# Anne      1
# Paul      1
# Name: count, dtype: int64

# %% [markdown]
# # Solve

# %% [markdown]
# ## Problem solving 1 >>  ID

# %%
df[df.duplicated(keep=False,subset=['Id'])]
# Out:
#    #   Id   Name    Birthday Gender  IsTeacher  #StudentS  Country    City
# 4  5  555   Alex  15/03/2000      A          1         23  Germany  Berlin
# 5  6  555  Peter  1983-12-01      M          1         10    Italy    Rome

# %% [markdown]
# replace 555 id in peter by 666
#
# 2 ways
#
# 1- replace
#
# 2- loc

# %%
df['Id'].replace(555,666)
# Out:
# 0       111
# 1       222
# 2       333
# 3       444
# 4       666
# 5       666
# 6       777
# 7       888
# 8       999
# 9    101010
# Name: Id, dtype: int64

# %%
df.loc[ 5 , 'Id' ] = 666

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      A          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          5  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6   Italy
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %%
df.iloc[ 5 , 1] = 666 # row  , column

# %%
df[df.duplicated(keep=False,subset=['Id'])]
# Out:
# Empty DataFrame
# Columns: [#, Id, Name, Birthday, Gender, IsTeacher, #StudentS, Country, City]
# Index: []

# %% [markdown]
# ## Problem solving 2 teacher

# %%
df[df['IsTeacher'] == 0]['#StudentS'].value_counts()
# Out:
# #StudentS
# 0    5
# 5    1
# Name: count, dtype: int64

# %%
df[(df['IsTeacher'] == 0) & (df['#StudentS'] == 5)]
# Out:
#    #   Id  Name  Birthday Gender  IsTeacher  #StudentS      Country    City
# 8  9  999  Anne  5/9/1992      F          0          5  Switzerland  Geneva

# %%
import numpy as np

df['#StudentS'] =  np.where(df['IsTeacher'] == 0, #condition
                            0,     #if true
                            df['#StudentS']  # if false
                            )

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      A          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          0  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6   Italy
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %%
df[(df['IsTeacher'] == 0) & (df['#StudentS'] == 5)]
# Out:
# Empty DataFrame
# Columns: [#, Id, Name, Birthday, Gender, IsTeacher, #StudentS, Country, City]
# Index: []

# %%
df[df['IsTeacher'] == 0]['#StudentS'].value_counts()
# Out:
# #StudentS
# 0    6
# Name: count, dtype: int64

# %% [markdown]
# ## Problem solving 3 >>  Gender A

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    5
# F    4
# A    1
# Name: count, dtype: int64

# %%
df[df['Gender'] == 'A']
# Out:
#    #   Id  Name    Birthday Gender  IsTeacher  #StudentS  Country    City
# 4  5  555  Alex  15/03/2000      A          1         23  Germany  Berlin

# %% [markdown]
# domain Knowledge says that in germany , Alex is Male

# %%
df['Gender'].replace('A','M',inplace=True)

# %% [markdown]
# general

# %%
df['Gender']=np.where( (df['Gender']!='F') & (df['Gender']!='M') ,    # condition                    
                        'M',                        # true
                        df['Gender']) # false

# %%
df['Gender'].mode()[0]
# Out:
# 'M'

# %%
df['Gender'].value_counts()
# Out:
# M    6
# F    4
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().idxmax()
# Out:
# 'M'

# %%
df['Gender']=np.where( (df['Gender']!='F') & (df['Gender']!='M') ,    # condition                    
                        df['Gender'].mode()[0] ,                        # true
                        df['Gender']) # false

# %% [markdown]
# ## Problem solving 4 >> City > Italy

# %% [markdown]
# ![DataQuality.png](attachment:DataQuality.png)

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      M          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          0  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6   Italy
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %%
# df[df['City']=='Italy']['Country'].values[0]
# Out:
# 'Italy'

# %%
# country_city = df[df['City']=='Italy']['Country'].values[0]
# country_city
# Out:
# 'Italy'

# %%
df[df['Country']== 'Italy']['City'].value_counts().idxmax()
# Out:
# 'Italy'

# %%
df['City'].replace(
                   'Italy',
                   df[df['Country']== 'Italy']['City'].value_counts().idxmax(),
                   inplace=True
                   )

# %%
df['City'] = np.where(df['Country'] == 'Italy',
                      'Rome',
                      df['City'])

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      M          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          0  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6    Rome
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %% [markdown]
# ## Problem solving 5 >> Country > misspeling

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      M          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          0  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Ytali
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6    Rome
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %% [markdown]
# task
#
# solve this problem
#
# using 3 techniques
#
# 1- replace
#
# 2- loc
#
# 3- where

# %%
df.loc[df['City'] == "Rome", 'Country'] = "Italy"

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      M          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          0  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Italy
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6   Italy
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %% [markdown]
# ## Problem solving 6 >> City > Null

# %%
df
# Out:
#     #      Id    Name    Birthday Gender  IsTeacher  #StudentS      Country  \
# 0   1     111    John  31/12/1990      M          0          0      Ireland
# 1   2     222    Mery  15/10/1978      F          1         15      Iceland
# 2   3     333   Alice  19/04/2000      F          0          0        Spain
# 3   4     444    Mark   1/11/1997      M          0          0       France
# 4   5     555    Alex  15/03/2000      M          1         23      Germany
# 5   6     666   Peter  1983-12-01      M          1         10        Italy
# 6   7     777  Calvin    5/5/1995      M          0          0        Italy
# 7   8     888  Roxane    3/8/1948      F          0          0     Portugal
# 8   9     999    Anne    5/9/1992      F          0          0  Switzerland
# 9  10  101010    Paul  14/11/1992      M          1         26        Italy
#
#      City
# 0  Dublin
# 1     NaN
# 2  Madrid
# 3   Paris
# 4  Berlin
# 5    Rome
# 6   Italy
# 7  Lisbon
# 8  Geneva
# 9    Rome

# %% [markdown]
# Refer this problem to Business team
#
# what is the city of iceland ?
#
# Reykjavik

# %%
df['City'].fillna('Reykjavik',inplace=True)

# %% [markdown]
# ## Problem solving 7 >> Datetime

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          10 non-null     int64
#  1   Id         10 non-null     int64
#  2   Name       10 non-null     object
#  3   Birthday   10 non-null     object
#  4   Gender     10 non-null     object
#  5   IsTeacher  10 non-null     int64
#  6   #StudentS  10 non-null     int64
#  7   Country    10 non-null     object
#  8   City       10 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 852.0+ bytes

# %%
df['Birthday']
# Out:
# 0    31/12/1990
# 1    15/10/1978
# 2    19/04/2000
# 3     1/11/1997
# 4    15/03/2000
# 5    1983-12-01
# 6      5/5/1995
# 7      3/8/1948
# 8      5/9/1992
# 9    14/11/1992
# Name: Birthday, dtype: object

# %%
# Convert the 'Date' column to datetime using pd.to_datetime()
df['Birthday'] = pd.to_datetime(df['Birthday'],format='%d/%m/%Y') #%d/%m/%Y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Program Files\Microsoft SQL Server\150\PYTHON_SERVER\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-c24ed9f038b3> in <module>
#       1 # Convert the 'Date' column to datetime using pd.to_datetime()
# ...

# %%
df['Birthday'].replace('1983-12-01','01/12/1983',inplace=True) # مرفـــــوض

# %%
df['Birthday']
# Out:
# 0    31/12/1990
# 1    15/10/1978
# 2    19/04/2000
# 3     1/11/1997
# 4    15/03/2000
# 5    01/12/1983
# 6      5/5/1995
# 7      3/8/1948
# 8      5/9/1992
# 9    14/11/1992
# Name: Birthday, dtype: object

# %%
df['Birthday'] = pd.to_datetime(df['Birthday'])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_2680\3789564390.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Birthday'] = pd.to_datetime(df['Birthday'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          10 non-null     int64
#  1   Id         10 non-null     int64
#  2   Name       10 non-null     object
#  3   Birthday   10 non-null     datetime64[ns]
#  4   Gender     10 non-null     object
#  5   IsTeacher  10 non-null     int64
#  6   #StudentS  10 non-null     int64
#  7   Country    10 non-null     object
#  8   City       10 non-null     object
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 852.0+ bytes
