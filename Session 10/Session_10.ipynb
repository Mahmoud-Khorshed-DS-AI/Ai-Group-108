# %% [markdown]
# ## 7 Other Functions in pandas

# %%
import pandas as pd

# %%
file_name = 'movies.csv'
data = pd.read_csv(file_name)
data.head()
# Out:
#                 title rating  year  runtime
# 0       Almost Famous      R  2000    122.0
# 1        American Pie      R  1999     95.0
# 2  Back to the Future     PG  1985    116.0
# 3        Blade Runner      R  1982    117.0
# 4   Blood for Dracula      R  1974    106.0

# %%
# pd.read_excel(filename)	#From an Excel file    xlsx format

# %% [markdown]
# ### 4- Data Cleaning

# %%
df.sample()
# Out:
#      title rating  year  runtime
# 25  Psycho      R  1960      NaN

# %%
df.columns
# Out:
# Index(['title', 'rating', 'year', 'runtime'], dtype='object')

# %%
df.columns = ['Title','Rating','Year','Runtime']  #Rename columns
df.sample(2)
# Out:
#            Title Rating  Year  Runtime
# 3   Blade Runner      R  1982    117.0
# 27       Super 8  PG-13  2011    112.0

# %%
df.rename(columns={'Year':'Year_Prod'},inplace=True)

# %%
df.sample()
# Out:
#                  Title Rating  Year  Runtime
# 19  Millennium Actress     PG  2001     87.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    30 non-null     object
#  1   Rating   30 non-null     object
#  2   Year     30 non-null     int64
#  3   Runtime  28 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ KB

# %%
df['Title'] = df['Title'].astype('string') # str	#Convert the datatype of the series to float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      30 non-null     string
#  1   Rating     30 non-null     object
#  2   Year_Prod  30 non-null     int64
#  3   Runtime    28 non-null     float64
# dtypes: float64(1), int64(1), object(1), string(1)
# memory usage: 1.1+ KB

# %%
df['Year_Prod'] = df['Year_Prod'].astype(float)	#Convert the datatype of the series to float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      30 non-null     string
#  1   Rating     30 non-null     object
#  2   Year_Prod  30 non-null     float64
#  3   Runtime    28 non-null     float64
# dtypes: float64(2), object(1), string(1)
# memory usage: 1.1+ KB

# %%
df
# Out:
#                       Title     Rating  Year_Prod  Runtime
# 0             Almost Famous          R     2000.0    122.0
# 1              American Pie          R     1999.0     95.0
# 2        Back to the Future         PG     1985.0    116.0
# 3              Blade Runner          R     1982.0    117.0
# 4         Blood for Dracula          R     1974.0    106.0
# 5               Blue Velvet          R     1986.0    120.0
# 6        The Breakfast Club          R     1985.0     97.0
# 7                  Clueless      PG-13     1995.0      NaN
# 8            Cool Hand Luke         GP     1967.0    127.0
# 9                 The Craft          R     1996.0    101.0
# 10           Doctor Zhivago      PG-13     1965.0    197.0
# 11                  el Topo  Not Rated     1970.0    125.0
# 12                Evil Dead      NC-17     1981.0     85.0
# 13             Ghostbusters         PG     1984.0    105.0
# 14                   Grease      PG-13     1978.0    110.0
# 15                 Heathers          R     1988.0    103.0
# 16                Labyrinth         PG     1986.0    101.0
# 17            The Lost Boys          R     1987.0     97.0
# 18               Mean Girls      PG-13     2004.0     97.0
# 19       Millennium Actress         PG     2001.0     87.0
# 20       My Neighbor Totoro          G     1988.0     86.0
# 21        Napoleon Dynamite         PG     2004.0     96.0
# 22  Pee-wee's Big Adventure         PG     1985.0     91.0
# 23           Pretty in Pink      PG-13     1986.0     97.0
# 24       The Princess Bride         PG     1987.0     98.0
# 25                   Psycho          R     1960.0      NaN
# 26              Stand by Me          R     1986.0     89.0
# 27                  Super 8      PG-13     2011.0    112.0
# 28                 superbad          R     2007.0    113.0
# 29                 WarGames         PG     1983.0    114.0

# %%
df.replace('8','Eight',inplace=False)	#Replace all values equal to 8 with 'Eight'
# Out:
#                      TITLE_    RATING_   YEAR_  RUNTIME_
# 0             Almost Famous          R  2000.0     122.0
# 1              American Pie          R  1999.0      95.0
# 2        Back to the Future         PG  1985.0     116.0
# 3              Blade Runner          R  1982.0     117.0
# 4         Blood for Dracula          R  1974.0     106.0
# 5               Blue Velvet          R  1986.0     120.0
# 6        The Breakfast Club          R  1985.0      97.0
# 7                  Clueless      PG-13  1995.0       NaN
# 8            Cool Hand Luke         GP  1967.0     127.0
# 9                 The Craft          R  1996.0     101.0
# 10           Doctor Zhivago      PG-13  1965.0     197.0
# 11                  el Topo  Not Rated  1970.0     125.0
# 12                Evil Dead      NC-17  1981.0      85.0
# 13             Ghostbusters         PG  1984.0     105.0
# 14                   Grease      PG-13  1978.0     110.0
# 15                 Heathers          R  1988.0     103.0
# 16                Labyrinth         PG  1986.0     101.0
# 17            The Lost Boys          R  1987.0      97.0
# 18               Mean Girls      PG-13  2004.0      97.0
# 19       Millennium Actress         PG  2001.0      87.0
# 20       My Neighbor Totoro          G  1988.0      86.0
# 21        Napoleon Dynamite         PG  2004.0      96.0
# 22  Pee-wee's Big Adventure         PG  1985.0      91.0
# 23           Pretty in Pink      PG-13  1986.0      97.0
# 24       The Princess Bride         PG  1987.0      98.0
# 25                   Psycho          R  1960.0       NaN
# 26              Stand by Me          R  1986.0      89.0
# 27                  Super 8      PG-13  2011.0     112.0
# 28                 superbad          R  2007.0     113.0
# 29                 WarGames         PG  1983.0     114.0

# %%
df.replace('8','Eight',regex=True,inplace=False)	#Replace all values equal to 8 with 'Eight'
# Out:
#                      TITLE_    RATING_   YEAR_  RUNTIME_
# 0             Almost Famous          R  2000.0     122.0
# 1              American Pie          R  1999.0      95.0
# 2        Back to the Future         PG  1985.0     116.0
# 3              Blade Runner          R  1982.0     117.0
# 4         Blood for Dracula          R  1974.0     106.0
# 5               Blue Velvet          R  1986.0     120.0
# 6        The Breakfast Club          R  1985.0      97.0
# 7                  Clueless      PG-13  1995.0       NaN
# 8            Cool Hand Luke         GP  1967.0     127.0
# 9                 The Craft          R  1996.0     101.0
# 10           Doctor Zhivago      PG-13  1965.0     197.0
# 11                  el Topo  Not Rated  1970.0     125.0
# 12                Evil Dead      NC-17  1981.0      85.0
# 13             Ghostbusters         PG  1984.0     105.0
# 14                   Grease      PG-13  1978.0     110.0
# 15                 Heathers          R  1988.0     103.0
# 16                Labyrinth         PG  1986.0     101.0
# 17            The Lost Boys          R  1987.0      97.0
# 18               Mean Girls      PG-13  2004.0      97.0
# 19       Millennium Actress         PG  2001.0      87.0
# 20       My Neighbor Totoro          G  1988.0      86.0
# 21        Napoleon Dynamite         PG  2004.0      96.0
# 22  Pee-wee's Big Adventure         PG  1985.0      91.0
# 23           Pretty in Pink      PG-13  1986.0      97.0
# 24       The Princess Bride         PG  1987.0      98.0
# 25                   Psycho          R  1960.0       NaN
# 26              Stand by Me          R  1986.0      89.0
# 27              Super Eight      PG-13  2011.0     112.0
# 28                 superbad          R  2007.0     113.0
# 29                 WarGames         PG  1983.0     114.0

# %%
df.replace(1960,1959,inplace=False)	#Replace all values equal to 1960 with 1959
# Out:
#                      TITLE_    RATING_   YEAR_  RUNTIME_
# 0             Almost Famous          R  2000.0     122.0
# 1              American Pie          R  1999.0      95.0
# 2        Back to the Future         PG  1985.0     116.0
# 3              Blade Runner          R  1982.0     117.0
# 4         Blood for Dracula          R  1974.0     106.0
# 5               Blue Velvet          R  1986.0     120.0
# 6        The Breakfast Club          R  1985.0      97.0
# 7                  Clueless      PG-13  1995.0       NaN
# 8            Cool Hand Luke         GP  1967.0     127.0
# 9                 The Craft          R  1996.0     101.0
# 10           Doctor Zhivago      PG-13  1965.0     197.0
# 11                  el Topo  Not Rated  1970.0     125.0
# 12                Evil Dead      NC-17  1981.0      85.0
# 13             Ghostbusters         PG  1984.0     105.0
# 14                   Grease      PG-13  1978.0     110.0
# 15                 Heathers          R  1988.0     103.0
# 16                Labyrinth         PG  1986.0     101.0
# 17            The Lost Boys          R  1987.0      97.0
# 18               Mean Girls      PG-13  2004.0      97.0
# 19       Millennium Actress         PG  2001.0      87.0
# 20       My Neighbor Totoro          G  1988.0      86.0
# 21        Napoleon Dynamite         PG  2004.0      96.0
# 22  Pee-wee's Big Adventure         PG  1985.0      91.0
# 23           Pretty in Pink      PG-13  1986.0      97.0
# 24       The Princess Bride         PG  1987.0      98.0
# 25                   Psycho          R  1959.0       NaN
# 26              Stand by Me          R  1986.0      89.0
# 27                  Super 8      PG-13  2011.0     112.0
# 28                 superbad          R  2007.0     113.0
# 29                 WarGames         PG  1983.0     114.0

# %%
df.replace(np.nan,0,inplace=False)	#Replace all values equal to 8 with 'Eight'
# Out:
#                      TITLE_    RATING_   YEAR_  RUNTIME_
# 0             Almost Famous          R  2000.0     122.0
# 1              American Pie          R  1999.0      95.0
# 2        Back to the Future         PG  1985.0     116.0
# 3              Blade Runner          R  1982.0     117.0
# 4         Blood for Dracula          R  1974.0     106.0
# 5               Blue Velvet          R  1986.0     120.0
# 6        The Breakfast Club          R  1985.0      97.0
# 7                  Clueless      PG-13  1995.0       0.0
# 8            Cool Hand Luke         GP  1967.0     127.0
# 9                 The Craft          R  1996.0     101.0
# 10           Doctor Zhivago      PG-13  1965.0     197.0
# 11                  el Topo  Not Rated  1970.0     125.0
# 12                Evil Dead      NC-17  1981.0      85.0
# 13             Ghostbusters         PG  1984.0     105.0
# 14                   Grease      PG-13  1978.0     110.0
# 15                 Heathers          R  1988.0     103.0
# 16                Labyrinth         PG  1986.0     101.0
# 17            The Lost Boys          R  1987.0      97.0
# 18               Mean Girls      PG-13  2004.0      97.0
# 19       Millennium Actress         PG  2001.0      87.0
# 20       My Neighbor Totoro          G  1988.0      86.0
# 21        Napoleon Dynamite         PG  2004.0      96.0
# 22  Pee-wee's Big Adventure         PG  1985.0      91.0
# 23           Pretty in Pink      PG-13  1986.0      97.0
# 24       The Princess Bride         PG  1987.0      98.0
# 25                   Psycho          R  1960.0       0.0
# 26              Stand by Me          R  1986.0      89.0
# 27                  Super 8      PG-13  2011.0     112.0
# 28                 superbad          R  2007.0     113.0
# 29                 WarGames         PG  1983.0     114.0

# %% [markdown]
# **insigh**
#
# - None

# %%
file_name = 'movies.csv'
data = pd.read_csv(file_name)
data.head()
# Out:
#                 title rating  year  runtime
# 0       Almost Famous      R  2000    122.0
# 1        American Pie      R  1999     95.0
# 2  Back to the Future     PG  1985    116.0
# 3        Blade Runner      R  1982    117.0
# 4   Blood for Dracula      R  1974    106.0

# %% [markdown]
# ### 4- Data Cleaning

# %% [markdown]
#  TasK
#
# 1- set index year
#
#
# 2- get 1982 data by calling the index

# %%
data.set_index('year',inplace=True)	#Change the index

# %%
data
# Out:
#                         title     rating  runtime
# year
# 2000            Almost Famous          R    122.0
# 1999             American Pie          R     95.0
# 1985       Back to the Future         PG    116.0
# 1982             Blade Runner          R    117.0
# 1974        Blood for Dracula          R    106.0
# 1986              Blue Velvet          R    120.0
# 1985       The Breakfast Club          R     97.0
# 1995                 Clueless      PG-13      NaN
# 1967           Cool Hand Luke         GP    127.0
# 1996                The Craft          R    101.0
# 1965           Doctor Zhivago      PG-13    197.0
# 1970                  el Topo  Not Rated    125.0
# 1981                Evil Dead      NC-17     85.0
# 1984             Ghostbusters         PG    105.0
# 1978                   Grease      PG-13    110.0
# 1988                 Heathers          R    103.0
# 1986                Labyrinth         PG    101.0
# 1987            The Lost Boys          R     97.0
# 2004               Mean Girls      PG-13     97.0
# 2001       Millennium Actress         PG     87.0
# 1988       My Neighbor Totoro          G     86.0
# 2004        Napoleon Dynamite         PG     96.0
# 1985  Pee-wee's Big Adventure         PG     91.0
# 1986           Pretty in Pink      PG-13     97.0
# 1987       The Princess Bride         PG     98.0
# 1960                   Psycho          R      NaN
# 1986              Stand by Me          R     89.0
# 2011                  Super 8      PG-13    112.0
# 2007                 superbad          R    113.0
# 1983                 WarGames         PG    114.0

# %%
data.loc[1960]
# Out:
# title      Psycho
# rating          R
# runtime       NaN
# Name: 1960, dtype: object

# %%
data.reset_index(inplace=True)

# %%
path = 'movies.csv'
data = pd.read_csv(path)
data.head()
# Out:
#                 title rating  year  runtime
# 0       Almost Famous      R  2000    122.0
# 1        American Pie      R  1999     95.0
# 2  Back to the Future     PG  1985    116.0
# 3        Blade Runner      R  1982    117.0
# 4   Blood for Dracula      R  1974    106.0

# %% [markdown]
# ### 5- Filter, Sort, and Groupby

# %%
path = 'movies.csv'
data = pd.read_csv(path)
df = data.copy()
df.sample(2)
# Out:
#              title rating  year  runtime
# 10  Doctor Zhivago  PG-13  1965    197.0
# 1     American Pie      R  1999     95.0

# %%
df[df['year'] > 2000]	#Rows where the column col is greater than 2000
# Out:
#                  title rating  year  runtime
# 18          Mean Girls  PG-13  2004     97.0
# 19  Millennium Actress     PG  2001     87.0
# 21   Napoleon Dynamite     PG  2004     96.0
# 27             Super 8  PG-13  2011    112.0
# 28            superbad      R  2007    113.0

# %%
df[df['runtime'] > 130]	#Rows where the column col is greater than 130
# Out:
#              title rating  year  runtime
# 10  Doctor Zhivago  PG-13  1965    197.0

# %%
df.isnull().sum()
# Out:
# title      0
# rating     0
# year       0
# runtime    2
# dtype: int64

# %%
df[df['runtime'].isnull()]
# Out:
#        title rating  year  runtime
# 7   Clueless  PG-13  1995      NaN
# 25    Psycho      R  1960      NaN

# %% [markdown]
# &
#
# |
#
# ~

# %%
df[ (df['runtime'] > 100) & (df['runtime'] < 110)]	#Rows where 95 > col > 110
# Out:
#                 title rating  year  runtime
# 4   Blood for Dracula      R  1974    106.0
# 9           The Craft      R  1996    101.0
# 13       Ghostbusters     PG  1984    105.0
# 15           Heathers      R  1988    103.0
# 16          Labyrinth     PG  1986    101.0

# %%
# df[(df['runtime'] > 95) & ]	#Rows where 0.8 > col > 0.6

# %% [markdown]
# task
#
# rating = PG

# %%
df[(df['runtime'] > 95) &  (df['rating'] == "PG")]
# Out:
#                  title rating  year  runtime
# 2   Back to the Future     PG  1985    116.0
# 13        Ghostbusters     PG  1984    105.0
# 16           Labyrinth     PG  1986    101.0
# 21   Napoleon Dynamite     PG  2004     96.0
# 24  The Princess Bride     PG  1987     98.0
# 29            WarGames     PG  1983    114.0

# %%
df[df['rating'] == "PG"]
# Out:
#                       title rating  year  runtime
# 2        Back to the Future     PG  1985    116.0
# 13             Ghostbusters     PG  1984    105.0
# 16                Labyrinth     PG  1986    101.0
# 19       Millennium Actress     PG  2001     87.0
# 21        Napoleon Dynamite     PG  2004     96.0
# 22  Pee-wee's Big Adventure     PG  1985     91.0
# 24       The Princess Bride     PG  1987     98.0
# 29                 WarGames     PG  1983    114.0

# %%
# = # Assigning   

# == # are you equal  ,,,,,  Compare

# %% [markdown]
# get the average of runtime when year > 1990

# %%
df[df['year'] < 1990]['runtime'].mean()
# Out:
# 109.05

# %%
df.sort_values('year')	#Sort values by col1 in ascending order
# Out:
#                       title     rating  year  runtime
# 25                   Psycho          R  1960      NaN
# 10           Doctor Zhivago      PG-13  1965    197.0
# 8            Cool Hand Luke         GP  1967    127.0
# 11                  el Topo  Not Rated  1970    125.0
# 4         Blood for Dracula          R  1974    106.0
# 14                   Grease      PG-13  1978    110.0
# 12                Evil Dead      NC-17  1981     85.0
# 3              Blade Runner          R  1982    117.0
# 29                 WarGames         PG  1983    114.0
# 13             Ghostbusters         PG  1984    105.0
# 6        The Breakfast Club          R  1985     97.0
# 2        Back to the Future         PG  1985    116.0
# 22  Pee-wee's Big Adventure         PG  1985     91.0
# 5               Blue Velvet          R  1986    120.0
# 26              Stand by Me          R  1986     89.0
# 16                Labyrinth         PG  1986    101.0
# 23           Pretty in Pink      PG-13  1986     97.0
# 17            The Lost Boys          R  1987     97.0
# 24       The Princess Bride         PG  1987     98.0
# 15                 Heathers          R  1988    103.0
# 20       My Neighbor Totoro          G  1988     86.0
# 7                  Clueless      PG-13  1995      NaN
# 9                 The Craft          R  1996    101.0
# 1              American Pie          R  1999     95.0
# 0             Almost Famous          R  2000    122.0
# 19       Millennium Actress         PG  2001     87.0
# 18               Mean Girls      PG-13  2004     97.0
# 21        Napoleon Dynamite         PG  2004     96.0
# 28                 superbad          R  2007    113.0
# 27                  Super 8      PG-13  2011    112.0

# %%
df.sort_values('year',ascending=False)	#Sort values by col2 in descending order.5
# Out:
#                       title     rating  year  runtime
# 27                  Super 8      PG-13  2011    112.0
# 28                 superbad          R  2007    113.0
# 21        Napoleon Dynamite         PG  2004     96.0
# 18               Mean Girls      PG-13  2004     97.0
# 19       Millennium Actress         PG  2001     87.0
# 0             Almost Famous          R  2000    122.0
# 1              American Pie          R  1999     95.0
# 9                 The Craft          R  1996    101.0
# 7                  Clueless      PG-13  1995      NaN
# 20       My Neighbor Totoro          G  1988     86.0
# 15                 Heathers          R  1988    103.0
# 17            The Lost Boys          R  1987     97.0
# 24       The Princess Bride         PG  1987     98.0
# 5               Blue Velvet          R  1986    120.0
# 26              Stand by Me          R  1986     89.0
# 16                Labyrinth         PG  1986    101.0
# 23           Pretty in Pink      PG-13  1986     97.0
# 22  Pee-wee's Big Adventure         PG  1985     91.0
# 2        Back to the Future         PG  1985    116.0
# 6        The Breakfast Club          R  1985     97.0
# 13             Ghostbusters         PG  1984    105.0
# 29                 WarGames         PG  1983    114.0
# 3              Blade Runner          R  1982    117.0
# 12                Evil Dead      NC-17  1981     85.0
# 14                   Grease      PG-13  1978    110.0
# 4         Blood for Dracula          R  1974    106.0
# 11                  el Topo  Not Rated  1970    125.0
# 8            Cool Hand Luke         GP  1967    127.0
# 10           Doctor Zhivago      PG-13  1965    197.0
# 25                   Psycho          R  1960      NaN

# %%
df.groupby('rating')['runtime'].mean()
# Out:
# rating
# G             86.000000
# GP           127.000000
# NC-17         85.000000
# Not Rated    125.000000
# PG           101.000000
# PG-13        122.600000
# R            105.454545
# Name: runtime, dtype: float64

# %%
df.groupby('year')['title'].count()
# Out:
# year
# 1960    1
# 1965    1
# 1967    1
# 1970    1
# 1974    1
# 1978    1
# 1981    1
# 1982    1
# 1983    1
# 1984    1
# 1985    3
# 1986    4
# 1987    2
# 1988    2
# 1995    1
# 1996    1
# 1999    1
# 2000    1
# 2001    1
# 2004    2
# 2007    1
# 2011    1
# Name: title, dtype: int64

# %% [markdown]
# ### 6- Join/Combine

# %%
row_A1 = {'Nid':1,'Add':'Alex','Age':25}
row_A2 = {'Nid':2,'Add':'Cairo','Age':30}
row_A3 = {'Nid':4,'Add':'behira','Age':55}
row_A4 = {'Nid':10,'Add':'menof','Age':64}
row_A5 = {'Nid':15,'Add':'alamin','Age':20}
row_A6 = {'Nid':20,'Add':'Aswan','Age':15}

Data_A = pd.DataFrame([row_A1,row_A2,row_A3,
                        row_A4,row_A5,row_A6])

Data_A
# Out:
#    Nid     Add  Age
# 0    1    Alex   25
# 1    2   Cairo   30
# 2    4  behira   55
# 3   10   menof   64
# 4   15  alamin   20
# 5   20   Aswan   15

# %%
row_B1 = {'Nid':20,'Sal':5000,'Mother':'Sara'}
row_B2 = {'Nid':10,'Sal':4500,'Mother':'Eman'}
row_B3 = {'Nid':16,'Sal':3000,'Mother':'Aml'}
row_B4 = {'Nid':5,'Sal':10000,'Mother':"Rania"}
row_B5 = {'Nid':3,'Sal':9700,'Mother':'Laila'}
row_B6 = {'Nid':2,'Sal':20000,'Mother':'Sahar'}
row_B7 = {'Nid':4,'Sal':6500,'Mother':'Hend'}

Data_B = pd.DataFrame([row_B1,row_B2,row_B3,
                        row_B4,row_B5,row_B6,
                        row_B7])

Data_B
# Out:
#    Nid    Sal Mother
# 0   20   5000   Sara
# 1   10   4500   Eman
# 2   16   3000    Aml
# 3    5  10000  Rania
# 4    3   9700  Laila
# 5    2  20000  Sahar
# 6    4   6500   Hend

# %%
Data_A
# Out:
#    Nid     Add  Age
# 0    1    Alex   25
# 1    2   CAiro   30
# 2    4  behira   55
# 3   10   menof   64
# 4   15  alamin   20
# 5   20   Aswan   15

# %%
Data_A.merge(Data_B,
            how='inner',
            on='Nid'
            )
# Out:
#    Nid     Add  Age    Sal Mother
# 0    2   CAiro   30  20000  Sahar
# 1    4  behira   55   6500   Hend
# 2   10   menof   64   4500   Eman
# 3   20   Aswan   15   5000   Sara

# %%
Data_A1 = Data_A.iloc[:-1]
Data_A1
# Out:
#    Nid     Add  Age
# 0    1    Alex   25
# 1    2   Cairo   30
# 2    4  behira   55
# 3   10   menof   64
# 4   15  alamin   20

# %%
row_A1 = {'Nid':1,'Add':'Alex','Age':25}
row_A2 = {'Nid':2,'Add':'Cairo','Age':30}
row_A3 = {'Nid':4,'Add':'behira','Age':55}


Data_A1 = pd.DataFrame([row_A1,row_A2,row_A3,
                        ])

Data_A1
# Out:
#    Nid     Add  Age
# 0    1    Alex   25
# 1    2   Cairo   30
# 2    4  behira   55

# %%
row_A4 = {'Nid':10,'Add':'menof','Age':64}
row_A5 = {'Nid':15,'Add':'alamin','Age':20}
row_A6 = {'Nid':20,'Add':'Aswan','Age':15}


Data_A2 = pd.DataFrame([row_A4,row_A5,row_A6,
                        ])

Data_A2
# Out:
#    Nid     Add  Age
# 0   10   menof   64
# 1   15  alamin   20
# 2   20   Aswan   15

# %%
pd.concat([Data_A1, Data_A2],
            axis=0
            )
# Out:
#    Nid     Add  Age
# 0    1    Alex   25
# 1    2   Cairo   30
# 2    4  behira   55
# 0   10   menof   64
# 1   15  alamin   20
# 2   20   Aswan   15

# %% [markdown]
# ### 7- Exporting Data

# %%
df_merge = Data_A.merge(Data_B,
                        how='inner',
                        on='Nid')

# %%
df_merge
# Out:
#    Nid     Add  Age    Sal Mother
# 0    2   CAiro   30  20000  Sahar
# 1    4  behira   55   6500   Hend
# 2   10   menof   64   4500   Eman
# 3   20   Aswan   15   5000   Sara

# %%
df_merge.to_csv('merge.csv', index=False  )	#Write to a CSV file

# %% [markdown]
# Task

# %%
df.to_excel(filename) #	Write to an Excel file

# %% [markdown]
# # Visualization
# # Abstract

# %% [markdown]
# Are you looking to level up your data visualization skills in Python?
#
#  Look no further!
#
#  Introducing the ultimate guide to 101 visualizations using just one dataset.
#
#  Whether you're a beginner or an experienced data scientist, this comprehensive guide will take you on a visual journey through various plotting techniques, insights, and patterns that can be explored with Python and a single dataset.
#
#
# In this guide, we cover everything you need to know to create impactful visualizations and effectively communicate your data-driven stories. From basic bar charts to intricate heatmaps, we've got you covered.
#
# The dataset we'll be using comprises diverse attributes, including purchase details, customer demographics, product categories, and more.
# Highlights of the Guide:
#
#
# • Basics of Data Visualization in Python
#
# • Line Plots: Uncovering Trends Over Time
#
# ![image.png](attachment:image.png)
#
# • Bar Charts: Comparing Categories and Quantities
#
# ![image-2.png](attachment:image-2.png)
#
# • Pie Charts: Analyzing Proportions
#
# ![image-3.png](attachment:image-3.png)
#
# • Scatter Plots: Identifying Relationships
#
# • Box Plots: Understanding Data Distribution
#
# • Heatmaps: Visualizing Correlations
#
# • Word Clouds: Exploring Textual Data ... and many more!
#
#
# So grab your Python toolkit and embark on this exciting data visualization adventure! By the end of this guide, you'll have mastered various visualization techniques and gained invaluable insights from a single dataset.

# %% [markdown]
# # 1- Getting Started with Data Visualization

# %% [markdown]
# Why Data Visualization Matters:
# Data visualization matters because it is a powerful tool that allows us to comprehend complex data and extract meaningful insights quickly and effectively
#
# - Storytelling and Communication
#
# - Decision-Making and Insights
#
# - Effective Reporting
#
#
# Effective Data Visualization:
#
# Choosing the Right Visualizations for Quantitative and Qualitative Data"
#
# - Quantitative Data Visualization:
#
#     - Histograms: Histograms are useful for visualizing the distribution of a single quantitative variable. They display the frequency or count of data points in predefined bins or intervals. Histograms are great for identifying patterns such as skewness, central tendency, and the presence of outliers
#
#     - Box Plots (Box-and-Whisker Plots): Box plots provide a concise summary of the distribution's central tendency, spread, and skewness. They show the median, quartiles, and possible outliers, making them ideal for comparing multiple quantitative variables or groups.
#
#     - Scatter Plots: Scatter plots are excellent for visualizing the relationship between two quantitative variables. They help identify correlations, clusters, and patterns in the data. Scatter plots are valuable for discovering any potential linear or nonlinear relationships.
#     - Line Charts: Line charts are commonly used to show trends and changes in data over time. They connect data points with straight lines, making them effective for visualizing time series data or any data with a continuous x-axis.
#     - Bar Charts: While often used for categorical data, bar charts can also display quantitative data when categories are grouped into intervals. This can be helpful for summarizing discrete quantitative data or comparing different ranges.
#     - Area Charts: Area charts are similar to line charts but represent the area under the line. They are useful for visualizing accumulated quantities over time or displaying stacked data.
#     - Heatmaps: Heatmaps are helpful for showing the intensity of a relationship between two quantitative variables. They use colors to represent data values and are effective for large datasets.
#
# For qualitative data, which represents categories or labels, different visualization types are recommended to effectively communicate insights. Here are some commonly used visualization types and their advantages for qualitative data:
#
# - Qualitative Data Visualization:
#
#     - Bar Charts: Bar charts are one of the most common ways to display qualitative data. They show the frequency or count of each category, making it easy to compare different categories.
#
#     - Pie Charts: Pie charts are useful for showing the composition or proportion of different categories within a whole. However, they are best used when the number of categories is relatively small (typically less than 5-6) to avoid clutter.
#
#     - Stacked Bar Charts: Stacked bar charts display the composition of a single variable as a whole, showing how each category contributes to the total. They are effective for comparing multiple qualitative variables or categories.
#
#     - Donut Charts: Donut charts are a variation of pie charts with a hole in the center. They can be used to show the same information as pie charts while offering more space for annotations or additional data.
#
#     - Word Clouds: Word clouds visually represent the frequency of words or terms in a text dataset. They are often used to highlight the most common terms or topics.
#
#     - Stacked Area Charts: Stacked area charts show the evolution of different qualitative categories over time, displaying how each category contributes to the whole.
#
#     - Chord Diagrams: Chord diagrams are used to visualize relationships between different categories or groups. They are useful for demonstrating connections and flows between entities.

# %% [markdown]
# # Python Libraries for Data Visualization

# %% [markdown]
# Python offers a variety of powerful libraries for data visualization that cater to different user needs and preferences. Each library has its strengths and weaknesses, making it important to choose the right one based on the specific visualization requirements.
# Below are some of the most popular Python libraries for data visualization:
#
# • Matplotlib: Matplotlib is one of the oldest and most widely used data visualization libraries in Python. It provides a flexible and comprehensive set of tools for creating static, interactive, and animated visualizations. While it requires more code for complex plots, Matplotlib's versatility makes it suitable for a wide range of visualization tasks.
#
# • Seaborn: Seaborn is built on top of Matplotlib and provides a high-level interface for creating attractive and informative statistical graphics. It simplifies the creation of complex visualizations, such as violin plots, pair plots, and correlation heatmaps, by providing convenient APIs. Seaborn is particularly useful for exploratory data analysis and works well with pandas DataFrames.
#
# • Plotly: Plotly is a popular library for creating interactive and web-based visualizations. It supports a wide range of chart types, including line charts, bar charts, scatter plots, and more. Plotly visualizations can be embedded in web applications or shared as standalone HTML files. It also has APIs for JavaScript, R, and other programming languages.
#
# • Pandas Plot: Pandas, a popular data manipulation library, also provides a simple plotting API for DataFrames and Series. While not as feature-rich as Matplotlib or Seaborn, it is convenient for quick exploratory visualizations directly from pandas data structures.

# %% [markdown]
# # Visualizations
#
# **IMPORTANT NOTE** : Each visual is presented in the following order:
#
# Visual # :   Title -      explanation,
#
#  Python code, and graph.

# %% [markdown]
# ## Reading Data and Simple EDA

# %%
# Import necessary libraries 
import pandas as pd 
#Graphic
import matplotlib.pyplot as plt 
# %matplotlib inline  
import seaborn as sns

# %%
# Load the dataset 
df = pd.read_csv('ecommerce_sales.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company_ID        10000 non-null  int64
#  1   Purchase_Date     10000 non-null  object
#  2   Product_Category  10000 non-null  object
#  3   Quantity          10000 non-null  int64
#  4   Total_Sales       10000 non-null  float64
#  5   Gender            10000 non-null  object
#  6   Marital_Status    10000 non-null  object
#  7   Price_Per_Unit    10000 non-null  float64
#  8   Customer_Type     10000 non-null  object
#  9   Age               10000 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 781.4+ KB

# %%
df.sample(3)
# Out:
#       Company_ID Purchase_Date Product_Category  Quantity  Total_Sales  \
# 9887           3    2021-03-29      Electronics         9    83.777947
# 5656           4    2020-07-13            Books         2   181.033628
# 709            2    2021-07-19         Clothing         1    83.756916
#
#       Gender Marital_Status  Price_Per_Unit       Customer_Type  Age
# 9887  Female        Widowed       33.362198  Returning Customer   77
# 5656  Female        Widowed       34.783558        New Customer   73
# 709   Female         Single       11.983233  Returning Customer   54

# %%
df.describe(include='all').T
# Out:
#                     count unique           top  freq        mean         std  \
# Company_ID        10000.0    NaN           NaN   NaN      3.4946    1.705245
# Purchase_Date       10000    732    2020-04-11    26         NaN         NaN
# Product_Category    10000      5         Books  2050         NaN         NaN
# Quantity          10000.0    NaN           NaN   NaN      5.4846    2.871339
# Total_Sales       10000.0    NaN           NaN   NaN  254.447723  141.335517
# Gender              10000      2        Female  5038         NaN         NaN
# Marital_Status      10000      4       Widowed  2566         NaN         NaN
# Price_Per_Unit    10000.0    NaN           NaN   NaN   27.464403   13.031501
# Customer_Type       10000      2  New Customer  5034         NaN         NaN
# Age               10000.0    NaN           NaN   NaN     48.7285   18.121872
#
#                         min         25%         50%         75%         max
# Company_ID              1.0         2.0         3.0         5.0         6.0
# Purchase_Date           NaN         NaN         NaN         NaN         NaN
# Product_Category        NaN         NaN         NaN         NaN         NaN
# Quantity                1.0         3.0         5.0         8.0        10.0
# Total_Sales       10.051904  133.163541  254.396524  376.643406  499.990299
# Gender                  NaN         NaN         NaN         NaN         NaN
# Marital_Status          NaN         NaN         NaN         NaN         NaN
# Price_Per_Unit     5.005398   16.204489   27.240523   38.835863   49.994841
# Customer_Type           NaN         NaN         NaN         NaN         NaN
# Age                    18.0        33.0        48.0        64.0        80.0

# %%
df.nunique()
# Out:
# Company_ID              6
# Purchase_Date         732
# Product_Category        5
# Quantity               10
# Total_Sales         10000
# Gender                  2
# Marital_Status          4
# Price_Per_Unit      10000
# Customer_Type           2
# Age                    63
# dtype: int64

# %% [markdown]
# ## Visualization 1: Bar Chart - Top 3 Product Categories by Sales:
#  Visualizing the total sales for the top 3 product categories using a bar chart.

# %%
top_3_categories =df.groupby('Product_Category')['Total_Sales'].sum().nlargest(3)
top_3_categories
# Out:
# Product_Category
# Books          522612.359452
# Electronics    515205.678891
# Home           513527.733013
# Name: Total_Sales, dtype: float64

# %%
top_3_categories.index
# Out:
# Index(['Books', 'Electronics', 'Home'], dtype='object', name='Product_Category')

# %%
top_3_categories.values
# Out:
# array([522612.35945243, 515205.67889108, 513527.73301304])

# %%
plt.bar(x=top_3_categories.index,
        height=top_3_categories.values
        ) 

plt.xticks(rotation=45)  # rotate the names on X-axis
plt.xlabel('Product Category')   # X-label
plt.ylabel('Total Sales') # y-label
plt.title('Top 3 Product Categories by Sales')

plt.show() # it is to show the fig

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nlargest.html
